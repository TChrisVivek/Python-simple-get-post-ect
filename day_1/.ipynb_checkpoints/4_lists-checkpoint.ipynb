# %%
items = ["bread","pasta","fruits","veggies"]
items
# Out:
# ['bread', 'pasta', 'fruits', 'veggies']

# %%
items[:2]
# Out:
# ['bread', 'pasta']

# %%
items.append("butter")
items
# Out:
# ['bread', 'pasta', 'fruits', 'veggies', 'butter', 'butter']

# %%
items[-2:]
# Out:
# ['fruits', 'veggies']

# %%
items.remove("butter")
items
# Out:
# ['bread', 'pasta', 'fruits', 'veggies']

# %%
items.insert(1,"butter")

# %%
items
# Out:
# ['bread', 'butter', 'pasta', 'fruits', 'veggies']

# %%
expenses = [30,1200,45,300]

# %%
expenses.sort()

# %%
expenses
# Out:
# [30, 45, 300, 1200]

# %%
expenses.reverse()
expenses
# Out:
# [30, 45, 300, 1200]

# %%
expenses.clear()
expenses
# Out:
# []

# %%
random = [1,2.0,'lalith',True]
random
# Out:
# [1, 2.0, 'lalith', True]
