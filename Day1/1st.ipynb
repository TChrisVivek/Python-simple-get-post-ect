# %%
print("Hello")
# Out:
# Hello

# %%
day_in_week = 5
working_hours_per_day = 9
working_hours_per_week = day_in_week * working_hours_per_day
print(working_hours_per_week)
# Out:
# 45

# %%
days_in_a_month = 22.3
working_hours_per_month = days_in_a_month * working_hours_per_day
print(working_hours_per_month)
# Out:
# 200.70000000000002

# %%
my_list = [1,2]
my_list.append(10)
my_list[2]
print(my_list, my_list[1])
# Out:
# [1, 2, 10] 2

# %%
string1 = "Day 1 is fun"
string2 = 'Day 2 ?'

# %%
string1[0]
# Out:
# 'D'

# %%
string1[6:]
# Out:
# 'is fun'

# %%
string1+" "+string2
# Out:
# 'Day 1 is fun Day 2 ?'

# %%
my_var = 1
if my_var >5:
    print("what is right")
elif my_var >10:
    print("what is wrong")
else :
    print("Null")
# Out:
# Null

# %%
my_array = [10, 20, 30]

i=0
while i < len(my_array):
    print(my_array[i])
    i += 1
# Out:
# 10
# 20
# 30

# %%
i=0
while i < len(my_list):
    print(my_list[i])
    i+=1
# Out:
# 1
# 2
# 10

# %%
my_list = [1,2,3,4,5]
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
# / Functions
def square(x):
    return x**2
def multiply(a,b):
    return a*b

square(multiply(10,2))
# Out:
# 400

# %%
def relu(x):
    if x > 0:
        return x
    else:
        return 0
relu(10)
# Out:
# 10

# %%
import numpy as np 
def euclidean_norm(vector):
    return np.linalg.norm(vector)


my_vector = [0.5,-1.2,3.3,4.5]
euclidean_norm(my_vector)
# Out:
# np.float64(5.729746940310715)

# %%
def vector_maximum(vector):

    return max(vector)

my_vector = [0.5, -1.2, 4.10, 4.10]
vector_maximum(my_vector)
# Out:
# 4.1

# %%
def bubble_sort(my_list):
    n = len(my_list)
    for i in range(n):
        for j in range(0, n-i-1):
            if my_list[j] > my_list[j+1]:
                my_list[j], my_list[j+1] = my_list[j+1], my_list[j]

    return my_list
my_list = [1, 10, 4, 2, 0]
print(bubble_sort(my_list))
# Out:
# [0, 1, 2, 4, 10]

# %%
name = input("Enter your name: ")
print(f"Hello, {name}!")
# Out:
# Hello, chris!

# %%
val = float(input("Enter a float: "))

print("Using round():", round(val, 2))

print(f"Using f-string: {val:.2f}")

rounded_arithmetic = int(val *100 + (0.5 if val >= 0 else -0.5)) / 100.0
print("Using integer arithmetic:", rounded_arithmetic)

print(" Raw 0.1 + 0.2 =", 0.1+0.2)
# Out:
# Using round(): 67.68
# Using f-string: 67.68
# Using integer arithmetic: 67.68
#  Raw 0.1 + 0.2 = 0.30000000000000004
